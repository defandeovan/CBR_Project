# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# === Path Folder ===
base_path = "/content/drive/My Drive/CBR_Project"
json_path = os.path.join(base_path, "data/processed/cases_all.json")
query_path = os.path.join(base_path, "data/eval/queries.json")

# === Load Data Kasus Lama ===
with open(json_path, "r", encoding="utf-8") as f:
    cases_data = json.load(f)

case_texts = [c["ringkasan_fakta"] if c["ringkasan_fakta"] else c["text_full"] for c in cases_data]
case_ids = [c["case_id"] for c in cases_data]

# === Load Query Uji ===
with open(query_path, "r", encoding="utf-8") as f:
    queries = json.load(f)

# === TF-IDF Vectorizer ===
vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = vectorizer.fit_transform(case_texts)  # Matriks TF-IDF semua kasus

# === Fungsi Retrieval ===
def retrieve(query: str, k: int = 5) -> list:
    query_vec = vectorizer.transform([query])
    scores = cosine_similarity(query_vec, tfidf_matrix).flatten()
    top_indices = scores.argsort()[::-1][:k]
    top_case_ids = [case_ids[i] for i in top_indices]
    return top_case_ids

# === Evaluasi Awal ===
print("🔍 Evaluasi 5-10 Query:")
print("="*60)
for q in queries:
    result = retrieve(q["query_text"], k=5)
    hit = any(gt in result for gt in q["ground_truth"])
    print(f"📌 Query ID: {q['query_id']}")
    print(f"🔎 Top-5 Hasil: {result}")
    print(f"✅ Ground Truth: {q['ground_truth']}")
    print(f"🎯 Hit: {hit}")
    print("-"*60)

print("✅ Evaluasi selesai.")
# Out:
# 🔍 Evaluasi 5-10 Query:
# ============================================================
# 📌 Query ID: 1
# 🔎 Top-5 Hasil: [1, 6, 22, 28, 9]
# ✅ Ground Truth: [1]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 2
# 🔎 Top-5 Hasil: [2, 9, 1, 19, 18]
# ✅ Ground Truth: [2]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 3
# 🔎 Top-5 Hasil: [3, 18, 19, 20, 9]
# ✅ Ground Truth: [3]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 4
# 🔎 Top-5 Hasil: [4, 21, 13, 19, 20]
# ✅ Ground Truth: [4]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 5
# 🔎 Top-5 Hasil: [5, 19, 18, 3, 20]
# ✅ Ground Truth: [5]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 6
# 🔎 Top-5 Hasil: [6, 1, 22, 28, 19]
# ✅ Ground Truth: [6]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 7
# 🔎 Top-5 Hasil: [7, 19, 20, 17, 16]
# ✅ Ground Truth: [7]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 8
# 🔎 Top-5 Hasil: [9, 19, 1, 20, 17]
# ✅ Ground Truth: [9]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 9
# 🔎 Top-5 Hasil: [10, 20, 19, 18, 1]
# ✅ Ground Truth: [10]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 10
# 🔎 Top-5 Hasil: [11, 7, 18, 30, 5]
# ✅ Ground Truth: [11]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 11
# 🔎 Top-5 Hasil: [12, 18, 5, 23, 25]
# ✅ Ground Truth: [12]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 12
# 🔎 Top-5 Hasil: [13, 21, 17, 16, 4]
# ✅ Ground Truth: [13]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 13
# 🔎 Top-5 Hasil: [14, 29, 15, 19, 20]
# ✅ Ground Truth: [14]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 14
# 🔎 Top-5 Hasil: [15, 14, 9, 19, 20]
# ✅ Ground Truth: [15]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 15
# 🔎 Top-5 Hasil: [16, 17, 21, 24, 13]
# ✅ Ground Truth: [16]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 16
# 🔎 Top-5 Hasil: [17, 16, 24, 28, 21]
# ✅ Ground Truth: [17]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 17
# 🔎 Top-5 Hasil: [18, 3, 19, 20, 23]
# ✅ Ground Truth: [18]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 18
# 🔎 Top-5 Hasil: [19, 20, 18, 9, 23]
# ✅ Ground Truth: [19]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 19
# 🔎 Top-5 Hasil: [20, 19, 18, 9, 23]
# ✅ Ground Truth: [20]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 20
# 🔎 Top-5 Hasil: [21, 13, 17, 16, 4]
# ✅ Ground Truth: [21]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 21
# 🔎 Top-5 Hasil: [22, 1, 6, 28, 9]
# ✅ Ground Truth: [22]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 22
# 🔎 Top-5 Hasil: [23, 29, 19, 18, 20]
# ✅ Ground Truth: [23]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 23
# 🔎 Top-5 Hasil: [24, 17, 16, 7, 18]
# ✅ Ground Truth: [24]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 24
# 🔎 Top-5 Hasil: [25, 18, 10, 30, 14]
# ✅ Ground Truth: [25]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 25
# 🔎 Top-5 Hasil: [26, 19, 20, 18, 23]
# ✅ Ground Truth: [26]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 26
# 🔎 Top-5 Hasil: [27, 1, 9, 19, 17]
# ✅ Ground Truth: [27]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 27
# 🔎 Top-5 Hasil: [28, 1, 6, 17, 19]
# ✅ Ground Truth: [28]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 28
# 🔎 Top-5 Hasil: [29, 23, 14, 19, 20]
# ✅ Ground Truth: [29]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 29
# 🔎 Top-5 Hasil: [30, 18, 4, 11, 10]
# ✅ Ground Truth: [30]
# 🎯 Hit: True
# ------------------------------------------------------------
# 📌 Query ID: 30
# 🔎 Top-5 Hasil: [31, 1, 19, 17, 9]
# ✅ Ground Truth: [31]
# 🎯 Hit: True
# ------------------------------------------------------------
# ✅ Evaluasi selesai.
